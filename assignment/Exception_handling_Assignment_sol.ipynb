# %% [markdown]
# 1. Write a Python program to handle a ZeroDivisionError exception when dividing a number by zero.

# %%
num1 = int(input('enter the divident'))
num2 = int(input('entert the divisor'))

try:
  ans = num1//num2
except ZeroDivisionError:
    print('cannot divide by zero')
else:
  print(ans)
# Out:
# enter the divident0
# entert the divisor8
# 0

# %% [markdown]
# 2. Write a Python program that prompts the user to input an integer and raises a ValueError exception if the input is not a valid integer.

# %%
num = input("enter the input: ")

try:
    num = int(num)
except ValueError:
    print("please provide correct integer value")
else:
    print("Valid integer:", num)
# Out:
# enter the input: 111a
# please provide correct integer value

# %% [markdown]
# 3. Write a Python program that opens a file and handles a FileNotFoundError exception if the file does not exist.

# %%
try:
  f = open("sample.txt",'r')
except FileNotFoundError:
  print("file not available")
# Out:
# file not available

# %%
try:
  f = open("sample.txt")
except Exception as e:
  print(e)
# Out:
# [Errno 2] No such file or directory: 'sample.txt'

# %% [markdown]
# 4. Write a Python program that prompts the user to input two numbers and raises a TypeError exception if the inputs are not numerical.

# %%
try:
    num1 = int(input("Enter first number: "))
    num2 = int(input("Enter second number: "))
except ValueError:
    raise TypeError("Only numbers allowed")
# Out:
# Enter first number: 5
# Enter second number: si
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4297/801384676.py in <cell line: 0>()
#       2     num1 = int(input("Enter first number: "))
# ----> 3     num2 = int(input("Enter second number: "))
#       4 except ValueError:
#
# ValueError: invalid literal for int() with base 10: 'si'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4297/801384676.py in <cell line: 0>()
#       3     num2 = int(input("Enter second number: "))
#       4 except ValueError:
# ----> 5     raise TypeError("Only numbers allowed")
#
# TypeError: Only numbers allowed

# %% [markdown]
# 5. Write a Python program that opens a file and handles a PermissionError exception if there is a permission issue.

# %%
try:
    with open("example.txt", "r") as file:
        print(file.read())

except PermissionError:
    print("Permission denied: Cannot open the file.")

except FileNotFoundError:
    print("File not found.")
# Out:
# File not found.

# %% [markdown]
# 6. Write a Python program that executes an operation on a list and handles an IndexError exception if the index is out of range.

# %%
my_list = [10, 20, 30, 40, 50]

try:
    index = int(input("Enter an index: "))
    print("Element at index:", my_list[index])

except IndexError:
    print("IndexError: The index is out of range.")

except ValueError:
    print("Please enter a valid number.")

except Exception as e:
    print("An unexpected error occurred:", e)
# Out:
# Enter an index: 8
# IndexError: The index is out of range.

# %% [markdown]
# 7. Write a Python program that executes division and handles an ArithmeticError exception if there is an arithmetic error.

# %%
try:
    num1 = int(input("Enter numerator: "))
    num2 = int(input("Enter denominator: "))

    result = num1 / num2
    print("Result", result)

except ArithmeticError:
    print("ArithmeticError occurred ")

except ValueError:
    print("Please enter valid numbees")

except Exception as e:
    print("An unexpected error occurred", e)
# Out:
# Enter numerator: 87
# Enter denominator: 9
# Result 9.666666666666666
